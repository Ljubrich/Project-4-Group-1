# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
credit_card_df = pd.read_csv("credit_card_data.csv")
credit_card_df.head()
# Out:
#         ID  MONTHS_BALANCE STATUS CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  \
# 0  5008806             0.0      C           M            Y               Y
# 1  5008808             0.0      0           F            N               Y
# 2  5008810             0.0      C           F            N               Y
# 3  5008811             0.0      C           F            N               Y
# 4  5008815             0.0      0           M            Y               Y
#
#    CNT_CHILDREN  AMT_INCOME_TOTAL      NAME_INCOME_TYPE  \
# 0             0          112500.0               Working
# 1             0          270000.0  Commercial associate
# 2             0          270000.0  Commercial associate
# 3             0          270000.0  Commercial associate
# 4             0          270000.0               Working
#
#              NAME_EDUCATION_TYPE    NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  \
# 0  Secondary / secondary special               Married  House / apartment
# ...

# %%
credit_card_df['STATUS'].replace({"0": 1, "2": 1, "3": 1, "4": 1, "5": 1, "C": 2, "X": 3}, inplace=True)
credit_card_df
# Out:
#             ID  MONTHS_BALANCE STATUS CODE_GENDER FLAG_OWN_CAR  \
# 0      5008806             0.0      0           M            Y
# 1      5008808             0.0      1           F            N
# 2      5008810             0.0      0           F            N
# 3      5008811             0.0      0           F            N
# 4      5008815             0.0      1           M            Y
# ...        ...             ...    ...         ...          ...
# 17038  5149828             0.0      1           M            Y
# 17039  5149834             0.0      0           F            N
# 17040  5149838             0.0      0           F            N
# 17041  5150049             0.0      1           F            N
# 17042  5150337             0.0      1           M            N
#
#       FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL      NAME_INCOME_TYPE  \
# 0                   Y             0          112500.0               Working
# ...

# %%
credit_card_df['STATUS'].replace({"0": 1, "2": 1, "3": 1, "4": 1, "5": 1, "C": 2, "X": 1}, inplace=True)
credit_card_df
# Out:
#             ID  MONTHS_BALANCE STATUS CODE_GENDER FLAG_OWN_CAR  \
# 0      5008806             0.0      0           M            Y
# 1      5008808             0.0      1           F            N
# 2      5008810             0.0      0           F            N
# 3      5008811             0.0      0           F            N
# 4      5008815             0.0      1           M            Y
# ...        ...             ...    ...         ...          ...
# 17038  5149828             0.0      1           M            Y
# 17039  5149834             0.0      0           F            N
# 17040  5149838             0.0      0           F            N
# 17041  5150049             0.0      1           F            N
# 17042  5150337             0.0      1           M            N
#
#       FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL      NAME_INCOME_TYPE  \
# 0                   Y             0          112500.0               Working
# ...

# %%
credit_card_df["STATUS"] = credit_card_df["STATUS"].astype(int)

# %%
# Convert categorical data to numeric with `pd.get_dummies`
credit_card_df_numeric = pd.get_dummies(credit_card_df, dtype=int)
credit_card_df_numeric = credit_card_df_numeric.drop(['AMT_INCOME_TOTAL', 'DAYS_BIRTH', 'DAYS_EMPLOYED','ID', 'MONTHS_BALANCE','CODE_GENDER_M', 'CODE_GENDER_F', 'CNT_CHILDREN', 'CNT_FAM_MEMBERS'], axis=1)
credit_card_df_numeric
# Out:
#        STATUS  FLAG_OWN_CAR_N  FLAG_OWN_CAR_Y  FLAG_OWN_REALTY_N  \
# 0           0               0               1                  0
# 1           1               1               0                  0
# 2           0               1               0                  0
# 3           0               1               0                  0
# 4           1               0               1                  0
# ...       ...             ...             ...                ...
# 17038       1               0               1                  0
# 17039       0               1               0                  0
# 17040       0               1               0                  0
# 17041       1               1               0                  0
# 17042       1               1               0                  0
#
#        FLAG_OWN_REALTY_Y  NAME_INCOME_TYPE_Commercial associate  \
# 0                      1                                      0
# ...

# %%
credit_card_df_numeric.columns
# Out:
# Index(['STATUS', 'FLAG_OWN_CAR_N', 'FLAG_OWN_CAR_Y', 'FLAG_OWN_REALTY_N',
#        'FLAG_OWN_REALTY_Y', 'NAME_INCOME_TYPE_Commercial associate',
#        'NAME_INCOME_TYPE_Pensioner', 'NAME_INCOME_TYPE_State servant',
#        'NAME_INCOME_TYPE_Student', 'NAME_INCOME_TYPE_Working',
#        'NAME_EDUCATION_TYPE_Academic degree',
#        'NAME_EDUCATION_TYPE_Higher education',
#        'NAME_EDUCATION_TYPE_Incomplete higher',
#        'NAME_EDUCATION_TYPE_Lower secondary',
#        'NAME_EDUCATION_TYPE_Secondary / secondary special',
#        'NAME_FAMILY_STATUS_Civil marriage', 'NAME_FAMILY_STATUS_Married',
#        'NAME_FAMILY_STATUS_Separated',
#        'NAME_FAMILY_STATUS_Single / not married', 'NAME_FAMILY_STATUS_Widow',
#        'NAME_HOUSING_TYPE_Co-op apartment',
#        'NAME_HOUSING_TYPE_House / apartment',
#        'NAME_HOUSING_TYPE_Municipal apartment',
#        'NAME_HOUSING_TYPE_Office apartment',
# ...

# %%
# Split our preprocessed data into our features and target arrays
y = credit_card_df_numeric["STATUS"].values
X = credit_card_df_numeric.drop(["STATUS"], axis=1).values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train[0])
hidden_nodes_layer1 =  50
hidden_nodes_layer2 = 28
hidden_nodes_layer3 = 28

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
)

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Third hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation="relu"))



# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="relu"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_20 (Dense)                │ (None, 50)             │         2,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_21 (Dense)                │ (None, 28)             │         1,428 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_22 (Dense)                │ (None, 28)             │           812 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_23 (Dense)                │ (None, 1)              │            29 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,469 (17.46 KB)
#  Trainable params: 4,469 (17.46 KB)
# ...

# %%
X_train.shape
# Out:
# (12782, 43)

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=30)
# Out:
# Epoch 1/30
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.6478 - loss: 1.1568
# Epoch 2/30
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6965 - loss: 0.6420
# Epoch 3/30
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7011 - loss: 0.6586
# Epoch 4/30
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7046 - loss: 0.6352
# Epoch 5/30
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7027 - loss: 0.6428
# Epoch 6/30
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7081 - loss: 0.6321
# Epoch 7/30
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7044 - loss: 0.6018
# Epoch 8/30
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7072 - loss: 0.6023
# Epoch 9/30
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7020 - loss: 0.6019
# Epoch 10/30
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7161 - loss: 0.5913
# Epoch 11/30
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7137 - loss: 0.5901
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 134/134 - 0s - 3ms/step - accuracy: 0.6987 - loss: 0.6983
# Loss: 0.6982561349868774, Accuracy: 0.698662281036377

# %%
# Export our model to HDF5 file
nn.save('Credit_Card_Model_Template.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
